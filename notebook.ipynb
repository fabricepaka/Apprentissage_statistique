# %% [markdown]
# # Introduction to Statistics in Python
# Run the hidden code cell below to import the data used in this course.

# %%
# Importing numpy and pandas
import numpy as np
import pandas as pd

# Importing the course datasets
deals = pd.read_csv("datasets/amir_deals.csv")
happiness = pd.read_csv("datasets/world_happiness.csv")
food = pd.read_csv("datasets/food_consumption.csv")

# %% [markdown]
# ## Take Notes
#
# Add notes about the concepts you've learned and code cells with code you want to keep.

# %% [markdown]
# _Add your notes here_

# %%
# Add your code snippets here

food.to_csv("food_consumption_download.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Add your code snippets here
# ----> 2 food_consumption
#
# NameError: name 'food_consumption' is not defined
